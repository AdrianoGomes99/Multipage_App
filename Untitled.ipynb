# %%
from pycaret.classification import predict_model, load_model
import pandas as pd
import numpy as np

# %%
# get relative data folder
MODEL_PATH = r"C:\Users\aog\OneDrive - Universidade de Aveiro\Desktop\Novo\A30\APP\Multipage_App\static\tuned_xgboost_pycaret"
# ML model for attrition prediction (xgboost in joblib format)
MODEL = load_model(MODEL_PATH)
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
MODEL
# Out:
# Pipeline(steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=['Sex',
#                                                             'Marital_Status',
#                                                             'Nationality',
#                                                             'Study_Area',
#                                                             'Area',
#                                                             'Contract_Type',
#                                                             'Schedule',
#                                                             'Morning_Schedule',
#                                                             'Afternoon_Schedule',
#                                                             'Night_Schedule',
#                                                             'Weekend_Schedule',
#                                                             'Day_off'],
# ...

# %%
MODEL??
# Out:
# Type:        Pipeline
# String form:
# Pipeline(steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=['Sex',
#                                                             'Marital_Status',
#                                                             'Nationality',
#                                                             'Study_Area',
#                                                             'Area',
#                                                             'Contract_Type',
#                                                             'Schedule',
#                                                             'Morning_Schedule',
#                                                             'Afternoon_Schedule',
#                                                             'Night_Schedule',
#                                                             'Weekend_Schedule',
#                                                             'Day_off'],
# ...

# %%
MODEL.get_params()
# Out:
# {'memory': None,
#  'steps': [('dtypes',
#    DataTypes_Auto_infer(categorical_features=['Sex', 'Marital_Status',
#                                               'Nationality', 'Study_Area', 'Area',
#                                               'Contract_Type', 'Schedule',
#                                               'Morning_Schedule',
#                                               'Afternoon_Schedule',
#                                               'Night_Schedule', 'Weekend_Schedule',
#                                               'Day_off'],
#                         features_todrop=['Employee_ID', 'Company',
#                                          'Employment_Status', 'Distance',
#                                          'Attrition1', 'Attrition2', 'Attrition4',
#                                          'Attrition5', 'Attrition6'],
#                         ml_usecase='classification',
#                         numerical_features=['Age', 'Number_Dependents',
# ...

# %%
import pickle

# %%
model = pickle.load(r"C:\Users\aog\OneDrive - Universidade de Aveiro\Desktop\Novo\FinalModel\tuned_xgboost_pycaret.pkl")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 model = pickle.load(r"C:\Users\aog\OneDrive - Universidade de Aveiro\Desktop\Novo\FinalModel\tuned_xgboost_pycaret.pkl")
#
# TypeError: file must have 'read' and 'readline' attributes

# %%
model.get_xgb_params()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 model.get_xgb_params()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'get_xgb_params'

# %%
model
# Out:
# array(['Age', 'Sex', 'Marital_Status', 'Number_Dependents',
#        'Number_Disabled_Dependents', 'Number_holders', 'Nationality',
#        'Qualifications', 'Academic_Qualifications', 'Study_Area', 'Area',
#        'Salary_Rate', 'Contract_Type', 'Float_Year_at_Company',
#        'Schedule', 'Morning_Schedule', 'Afternoon_Schedule',
#        'Night_Schedule', 'Weekend_Schedule', 'Day_off', 'Duration'],
#       dtype=object)
